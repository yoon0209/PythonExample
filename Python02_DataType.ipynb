# %%
a = 200
b = 33
if b>a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
age = 23
txt = f"My name is nayoung, I am {age}"
print(txt)
# Out:
# My name is nayoung, I am 23

# %%
a = "hello"
b = "world"
c = a + b
print(c)
# Out:
# helloworld

# %%
b = "hello, world"
print(b[-5:-2])
# Out:
# wor

# %%
b = "hello, world"
print(b[:5])
# Out:
# hello

# %%
a = "HEllo"
print(a)
# Out:
# HEllo

# %%
import random
print(random.randrange(1,10))
# Out:
# 4
