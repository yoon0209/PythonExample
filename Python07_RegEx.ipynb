# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
['ai', 'ai']
# Out:
# ['ai', 'ai']
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
[]
# Out:
# []
# []

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_21856\4009967224.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
None
# Out:
# None

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_21856\3697854446.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_21856\3056546710.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_21856\3056546710.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\wlwlq\AppData\Local\Temp\ipykernel_21856\21386051.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt)

# %%
import re
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
try:
    print(x)
except:
    print("An exception occurred")
# Out:
# <re.Match object; span=(12, 17), match='Spain'>

# %%
txt = f"The price is 49 dollars"
print(txt)
# Out:
# The price is 49 dollars

# %%
txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %%
price = 59
tax = 0.25
txt = f"The price is {price + (price * tax)} dollars"
print(txt)
# Out:
# The price is 73.75 dollars

# %%
fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %%
price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
result = None
if result is not None:
    print("Result is ready")
else:
    print("No result yet")
# Out:
# No result yet

# %%
name = input("Enter your name:")
print(f"Hello {name}")
# Out:
# Hello Yoon Na-Young

# %%
name = input("Enter your name:")
print(f"Hello {name}")
fav1 = input("What is your favorite animal:")
fav2 = input("What is your favorite color:")
fav3 = input("What is your favorite number:")
print(f"Do you want a {fav2} {fav1} with {fav3} legs?")
# Out:
# Hello Yoon Na-Young
# Do you want a Blue Puppy with 7 legs?
